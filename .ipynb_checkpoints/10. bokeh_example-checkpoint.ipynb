# %%
# Установка библиотеки
# !pip install bokeh==2.4.1

# для VS Code
#%pip install bokeh==2.4.1
# Out:
# Requirement already satisfied: bokeh==2.4.1 in c:\users\admin\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (1.20.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (2.11.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (3.10.0.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (21.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\admin\anaconda3\lib\site-packages (from bokeh==2.4.1) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.1) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging>=16.8->bokeh==2.4.1) (3.0.4)

# %% [markdown]
# ## Библиотека Bokeh
#
# Библиотека для интеркативной визуализации

# %%
import numpy as np
import pandas as pd

# %%
# загрузка данных

ykt_df = pd.read_excel("data/cities_of_Yakutia.xlsx")
ykt_df
# Out:
#             город  население  площадь  широта  долгота
# 0          Якутск     318768      122   62.00   129.70
# 1        Нерюнгри      57009       99   56.66   124.72
# 2         Вилюйск      11095       15   63.74   121.65
# 3           Ленск      23479       49   60.72   114.94
# 4           Алдан      20595       33   58.61   125.40
# 5       Олёкминск       9213       12   60.38   120.44
# 6   Среднеколымск       3489       20   67.46   153.70
# 7        Покровск       9256       11   61.48   129.14
# 8          Мирный      35223       15   62.54   113.98
# 9           Нюрба       9786       19   63.29   118.36
# 10         Томмот       6935       26   58.97   126.27
# 11        Удачный      11676        2   66.41   112.24
# 12      Верхоянск       1122       25   67.55   133.38

# %%
# функция для преобразования с сферической системы координат в цилиндрическую  систему координат для проекции Меркатора

def to_mercator(lat, lon):
    r_earth = 6378137.0
    
    x = r_earth * np.radians(lon)
    
    y = 180.0/np.pi * np.log(np.tan(np.pi/4.0 + np.radians(lat)/2.0)) * (x/lon)
    
    return pd.DataFrame(np.array([x,y]).T, columns=["меркатор_х", "меркатор_у"])

# %%
mercators = to_mercator(ykt_df["широта"], ykt_df["долгота"])
mercators
# Out:
#       меркатор_х    меркатор_у
# 0   1.443814e+07  8.859143e+06
# 1   1.388377e+07  7.690941e+06
# 2   1.354202e+07  9.284045e+06
# 3   1.279506e+07  8.561813e+06
# 4   1.395946e+07  8.096566e+06
# 5   1.340732e+07  8.484831e+06
# 6   1.710981e+07  1.028837e+07
# 7   1.437580e+07  8.736881e+06
# 8   1.268820e+07  8.988336e+06
# 9   1.317577e+07  9.171715e+06
# 10  1.405631e+07  8.173906e+06
# 11  1.249450e+07  9.989971e+06
# 12  1.484779e+07  1.031456e+07

# %%
# объединение DataFrameов

ykt_df[["меркатор_х", "меркатор_у"]] = mercators
ykt_df
# Out:
#             город  население  площадь  широта  долгота    меркатор_х  \
# 0          Якутск     318768      122   62.00   129.70  1.443814e+07
# 1        Нерюнгри      57009       99   56.66   124.72  1.388377e+07
# 2         Вилюйск      11095       15   63.74   121.65  1.354202e+07
# 3           Ленск      23479       49   60.72   114.94  1.279506e+07
# 4           Алдан      20595       33   58.61   125.40  1.395946e+07
# 5       Олёкминск       9213       12   60.38   120.44  1.340732e+07
# 6   Среднеколымск       3489       20   67.46   153.70  1.710981e+07
# 7        Покровск       9256       11   61.48   129.14  1.437580e+07
# 8          Мирный      35223       15   62.54   113.98  1.268820e+07
# 9           Нюрба       9786       19   63.29   118.36  1.317577e+07
# 10         Томмот       6935       26   58.97   126.27  1.405631e+07
# 11        Удачный      11676        2   66.41   112.24  1.249450e+07
# 12      Верхоянск       1122       25   67.55   133.38  1.484779e+07
#
#       меркатор_у
# 0   8.859143e+06
# 1   7.690941e+06
# 2   9.284045e+06
# 3   8.561813e+06
# 4   8.096566e+06
# 5   8.484831e+06
# 6   1.028837e+07
# 7   8.736881e+06
# 8   8.988336e+06
# 9   9.171715e+06
# 10  8.173906e+06
# 11  9.989971e+06
# 12  1.031456e+07

# %% [markdown]
# ### визуализация

# %%
# импорт библиотекеи bokeh
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, ColumnDataSource
from bokeh.tile_providers import get_provider, Vendors
from bokeh.palettes import Viridis
from bokeh.transform import log_cmap

# %%
ykt_df.columns
# Out:
# Index(['город', 'население', 'площадь', 'широта', 'долгота', 'меркатор_х',
#        'меркатор_у'],
#       dtype='object')

# %%
# показ визуализации в блокноте
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1384">Loading BokehJS ...</span>
#     </div>

# %%
# выбор тайлов (плиток) для карты

tile = get_provider(Vendors.ESRI_IMAGERY)

# %%
# указываем Bokeh на наш датафрейм в качестве источника данных 
source = ColumnDataSource(data=ykt_df)

# цветовая палитра
cmap = log_cmap(field_name="население",
                palette = Viridis[256], low=ykt_df["население"].min(),
               high = ykt_df["население"].max()
               )

#  всплывающие подсказки 
tooltips = [("Город", "@{город}"),("Площадь", "@{площадь}")]

# создание рисунка 
fig = figure(x_axis_type="mercator", y_axis_type="mercator",
            x_axis_label="долгота", y_axis_label="широта", tooltips=tooltips)

# добавление точек согласно координатам

fig.circle(x="меркатор_х", y="меркатор_у", source=source, color=cmap, size=5)

# добавление тайлов карт 

fig.add_tile(tile)

# показ карты 
show(fig)
# Out:
#   <div class="bk-root" id="f62bb3f0-3c81-4a04-9788-a93a54610d91" data-root-id="1764"></div>
